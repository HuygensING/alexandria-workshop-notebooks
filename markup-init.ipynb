# %%
from alexandria.notebook.alexandria_markup_proxy import AlexandriaMarkupProxy

alexandria = AlexandriaMarkupProxy("http://localhost:8080/", "http://192.168.99.100:9000/")
alice = alexandria.add_document('data/alice-excerpt.lmnl')
print(alice)
# Out:
# DocumentProxy::af7ce803-eb9d-46cd-89ac-10a2293cea29

# %%
print(alice.get_lmnl())
# Out:
# [excerpt}[p}
# Alice was beginning to get very tired of sitting by her sister on the bank,
# and of having nothing to do: once or twice she had peeped into the book her sister
# was reading, but it had no pictures or conversations in it,
# [q=a}and what is the use of a book,{q=a]
# thought Alice
# [q=a}without pictures or conversation?{q=a]
# {excerpt]{p]

# %%
alice.show_text_markup()
# Out:
# <a href="http://192.168.99.100:9000/svg/11097795-d5f6-4e10-86fb-60cd1747d68f.svg" target="_new" >open in new tab</a>

# %%
alice.show_markupdepth()
# Out:
# <a href="http://192.168.99.100:9000/svg/7ea011d7-0cb8-4ca6-b681-8f9889acd094.svg" target="_new" >open in new tab</a>

# %%
alice.show_matrix()
# Out:
# <a href="http://192.168.99.100:9000/svg/c80a31ce-c310-4222-8929-e00de7782151.svg" target="_new" >open in new tab</a>

# %%
alice.show_kdtree()
# Out:
# <a href="http://192.168.99.100:9000/svg/6b85b9f3-5ead-4d71-b43c-4a75126e98e9.svg" target="_new" >open in new tab</a>
